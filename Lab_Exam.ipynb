# %%
import numpy as np
import pandas as pd
import matplotlib as mp

# %% [markdown]
# print()

# %%
temperature = np.array([28,31,32,33,34,36])
print("Last 6 days Temperature Report:", temperature)
print("average of temp:", temperature.mean())
print("max temp :",temperature.max())
print("min temp :",temperature.min())
# Out:
# Last 6 days Temperature Report: [28 31 32 33 34 36]
# average of temp: 32.333333333333336
# max temp : 36
# min temp : 28

# %%
rainfall = np.array([112,89,98,45,23,12])
total_rainfall = rainfall.sum()
print("Total Rainfall from past 6 days :",total_rainfall)
# Out:
# Total Rainfall from past 6 days : 379

# %%
humidity = np.array([66,74,65,55,33,28])
wind = np.array([112,89,66,88,77,102])
days =np.array(["Monday","tuesday","wednesday","thursday","friday","saturday"])

df = pd.DataFrame(days,[temperature,rainfall,humidity,wind])
print(df)
# Out:
#                        0
# 28 112 66 112     Monday
# 31 89  74 89     tuesday
# 32 98  65 66   wednesday
# 33 45  55 88    thursday
# 34 23  33 77      friday
# 36 12  28 102   saturday

# %%
print(df)
# Out:
#                        0
# 28 112 66 112     Monday
# 31 89  74 89     tuesday
# 32 98  65 66   wednesday
# 33 45  55 88    thursday
# 34 23  33 77      friday
# 36 12  28 102   saturday
